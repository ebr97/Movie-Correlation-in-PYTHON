# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# Read in the data
df = pd.read_csv('movies.csv')

# Let's look at the data
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Cleaning the data process, step by step

# Checking the data to see if missing any

for col in df.columns:
    percent = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percent))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%
# year - 0.0%

# %%
# It seems like there are some null values, let's get rid of them
df = df.dropna()

#Let's check again to make sure that now we don't have any null values
for col in df.columns:
    percent = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percent))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%
# year - 0.0%

# %%
# Now I'll check the data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# year          int64
# dtype: object

# %%
# I'll change the budget and gross to int, there is no need for float data type

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head(5)
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
# After some digging into the data I saw that for some entries, year don't match up the released date. We need to change that

# I will get rid of the old year column
df.drop('year', axis = 1, inplace = True)
df
# Out:
#                                                 name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life    NaN      Drama
# 7664                                     Dream Round    NaN     Comedy
# 7665                                   Saving Mbango    NaN      Drama
# 7666                                    It's Just Us    NaN      Drama
# 7667                                       Tee em el    NaN     Horror
#
#                               released  score      votes         director  \
# ...

# %%
# Now let's add the year column with the correct data

df['year'] = int(df['released'].values.tolist()[0].split(',')[1][1:5])
df
# Out:
#                                                 name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life    NaN      Drama
# 7664                                     Dream Round    NaN     Comedy
# 7665                                   Saving Mbango    NaN      Drama
# 7666                                    It's Just Us    NaN      Drama
# 7667                                       Tee em el    NaN     Horror
#
#                               released  score      votes         director  \
# ...

# %%
# order the data by gross

df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
# To see all the data run the line bellow

# pd.set_option['display.max_rows', None]

# %%
# Remove any duplicates

df.drop_duplicates()

# The cleaning process comes to end
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
# Let's if there are any correlations

# Budget vs Gross

plt.scatter(x = 'budget', y = 'gross', data = df)
plt.title('Budget vs Gross')
plt.xlabel('Budget for film')
plt.ylabel('Gross earnings')
# Out:
# Text(0, 0.5, 'Gross earnings')

# %%
sns.regplot(x = 'budget', y = 'gross', data = df, line_kws={'color': 'red'})
plt.title('Budget vs Gross')
plt.xlabel('Budget for film')
plt.ylabel('Gross earnings')
# Out:
# Text(0, 0.5, 'Gross earnings')

# %%
# Let's start looking at correlation

correlation_matrix = df.corr()
correlation_matrix
# Out:
#             score     votes    budget     gross   runtime  year
# score    1.000000  0.474256  0.072001  0.222556  0.414068   NaN
# votes    0.474256  1.000000  0.439675  0.614751  0.352303   NaN
# budget   0.072001  0.439675  1.000000  0.740247  0.318695   NaN
# gross    0.222556  0.614751  0.740247  1.000000  0.275796   NaN
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000   NaN
# year          NaN       NaN       NaN       NaN       NaN   NaN

# %%
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

# seems like the high correlation is between budget and gross (0,74), another will be votes and gross (0,61)
# I wanna make note that correlation can be made only between numbers, and not strings
# Out:
# Text(33.0, 0.5, 'Movie features')

# %%
# Let's look for correlation between companies and gross
# We can make a numeric representation of the companies

df_numerized = df

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

#df_numerized.drop('year', axis = 1, inplace = True)
df_numerized
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1     3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3      204       4      4      1127    7.7   221000.0       889    1413  1474
# 4      732       6      4      1170    7.3   108000.0       719     351   271
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000.0        16    2390  1812
# 7649  3556       4      0       713    6.5   102000.0       852    2309   147
# 7650  1153       4      1       904    5.6    53000.0      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000.0       294    2091   640
# 7652  4090       3      0       370    6.8     3700.0       746    1184  1839
#
# ...

# %%
df
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1     3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3      204       4      4      1127    7.7   221000.0       889    1413  1474
# 4      732       6      4      1170    7.3   108000.0       719     351   271
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000.0        16    2390  1812
# 7649  3556       4      0       713    6.5   102000.0       852    2309   147
# 7650  1153       4      1       904    5.6    53000.0      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000.0       294    2091   640
# 7652  4090       3      0       370    6.8     3700.0       746    1184  1839
#
# ...

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

# It seems like the company that doesn't correlate with gross
# Out:
# Text(87.0, 0.5, 'Movie features')
